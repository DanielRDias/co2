# %% [markdown]
# <a href="https://www.kaggle.com/danielrpdias/co2-data-notebook?scriptVersionId=87675846" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import plotly.express as px

data=pd.read_csv('../input/co2-and-greenhouse-gas-emissions/owid-co2-data.csv')
data
# Out:
#       iso_code      country  year     co2  consumption_co2  co2_growth_prct  \
# 0          AFG  Afghanistan  1949   0.015              NaN              NaN
# 1          AFG  Afghanistan  1950   0.084              NaN           475.00
# 2          AFG  Afghanistan  1951   0.092              NaN             8.70
# 3          AFG  Afghanistan  1952   0.092              NaN             0.00
# 4          AFG  Afghanistan  1953   0.106              NaN            16.00
# ...        ...          ...   ...     ...              ...              ...
# 25199      ZWE     Zimbabwe  2016  10.738           12.153           -12.17
# 25200      ZWE     Zimbabwe  2017   9.582           11.248           -10.77
# 25201      ZWE     Zimbabwe  2018  11.854           13.163            23.72
# 25202      ZWE     Zimbabwe  2019  10.949           12.422            -7.64
# 25203      ZWE     Zimbabwe  2020  10.531              NaN            -3.82
#
# ...

# %%
data_clean = data[(data['co2'] > 0) & (data['country'] != 'World')]
data_clean
# Out:
#       iso_code      country  year     co2  consumption_co2  co2_growth_prct  \
# 0          AFG  Afghanistan  1949   0.015              NaN              NaN
# 1          AFG  Afghanistan  1950   0.084              NaN           475.00
# 2          AFG  Afghanistan  1951   0.092              NaN             8.70
# 3          AFG  Afghanistan  1952   0.092              NaN             0.00
# 4          AFG  Afghanistan  1953   0.106              NaN            16.00
# ...        ...          ...   ...     ...              ...              ...
# 25199      ZWE     Zimbabwe  2016  10.738           12.153           -12.17
# 25200      ZWE     Zimbabwe  2017   9.582           11.248           -10.77
# 25201      ZWE     Zimbabwe  2018  11.854           13.163            23.72
# 25202      ZWE     Zimbabwe  2019  10.949           12.422            -7.64
# 25203      ZWE     Zimbabwe  2020  10.531              NaN            -3.82
#
# ...

# %%
px.line(data_clean, x = 'year', y = 'co2', color='country')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
px.scatter(data_clean[data_clean['year']==2019], x="co2_per_capita", y="energy_per_capita",
           size="co2", color="country", hover_name="country", log_x=True, size_max=60)
# Out:
# <div>                            <div id="53473696-0fdb-4789-b961-a72d1eb9b5e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53473696-0fdb-4789-b961-a72d1eb9b5e6")) {                    Plotly.newPlot(                        "53473696-0fdb-4789-b961-a72d1eb9b5e6",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Afghanistan<br>co2_per_capita=%{x}<br>energy_per_capita=%{y}<br>co2=%{marker.size}<extra></extra>","hovertext":["Afghanistan"],"legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[12.147],"sizemode":"area","sizeref":5.724609166666667,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[0.319],"xaxis":"x","y":[null],"yaxis":"y","type":"scatter"},{"hovertemp
# ...

# %%
continent_data =  data[(data['country'].isin(['Europe', 'Africa', 'North America', 'South America', 'Oceania', 'Asia'])) & (data['co2'] > 0)]
continent_data
# Out:
#       iso_code        country  year       co2  consumption_co2  \
# 72         NaN         Africa  1884     0.022              NaN
# 73         NaN         Africa  1885     0.037              NaN
# 74         NaN         Africa  1886     0.048              NaN
# 75         NaN         Africa  1887     0.048              NaN
# 76         NaN         Africa  1888     0.081              NaN
# ...        ...            ...   ...       ...              ...
# 20888      NaN  South America  2016  1164.898         1240.096
# 20889      NaN  South America  2017  1156.734         1238.620
# 20890      NaN  South America  2018  1091.450         1173.851
# 20891      NaN  South America  2019  1065.510         1139.737
# 20892      NaN  South America  2020   994.160              NaN
#
#        co2_growth_prct  co2_growth_abs  trade_co2  co2_per_capita  \
# 72                 NaN             NaN        NaN           0.005
# 73               66.67           0.015        NaN           0.008
# ...

# %%
px.line(continent_data, x = 'year', y = 'co2_per_capita', color='country')
# Out:
# <div>                            <div id="71b82f8b-41c7-4247-a924-9e739f9caa4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71b82f8b-41c7-4247-a924-9e739f9caa4e")) {                    Plotly.newPlot(                        "71b82f8b-41c7-4247-a924-9e739f9caa4e",                        [{"hovertemplate":"country=Africa<br>year=%{x}<br>co2_per_capita=%{y}<extra></extra>","legendgroup":"Africa","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Africa","showlegend":true,"x":[1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930
# ...

# %%
px.line(continent_data, x = 'year', y = 'co2', color='country')
# Out:
# <div>                            <div id="ee20382c-76f0-45ae-bde7-83c6ebb131f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee20382c-76f0-45ae-bde7-83c6ebb131f8")) {                    Plotly.newPlot(                        "ee20382c-76f0-45ae-bde7-83c6ebb131f8",                        [{"hovertemplate":"country=Africa<br>year=%{x}<br>co2=%{y}<extra></extra>","legendgroup":"Africa","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Africa","showlegend":true,"x":[1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,
# ...

# %%
px.pie(continent_data, names='country', values='co2')
# Out:
# <div>                            <div id="339945d7-85e4-428a-bc71-20e9fc97405e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("339945d7-85e4-428a-bc71-20e9fc97405e")) {                    Plotly.newPlot(                        "339945d7-85e4-428a-bc71-20e9fc97405e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"country=%{label}<br>co2=%{value}<extra></extra>","labels":["Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa",
# ...
